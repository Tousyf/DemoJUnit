# %% [markdown]
# <a href="https://colab.research.google.com/github/Tousyf/DemoJUnit/blob/master/File_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age =  int(input("enter your age"))
if age>18:
  print("you are eligible for voting")
# Out:
# enter your age19
# you are eligible for voting

# %%
#f1=open("file1.txt", "x")

# %%
#f1 =  open("file1.txt", "rb")

# %%
#print(f1)

# %%
# !pwd
# Out:
# /content

# %%
f1=open("file1.txt", "x")

# %%
"""
Hi I am Touseef
and we discussing File handling in python
"""

# %%
f1=open("file1.txt", "r")
#f1=open("file1.txt")

# %%
print(f1.tell())
# Out:
# 0

# %%
data = f1.read()

# %%
print(data)
# Out:
# Hi I am Touseef
# and we discussing File handling in python

# %%
f1=open("file2.txt", "w")

# %%
f1=open("file1.txt", "w") #it erases all the content if file already exits

# %%
f1.write("Hello Students We are discusing File handling")
# Out:
# 45

# %%
print(f1.tell())
# Out:
# 45

# %%
#print(f1.read())

# %%
f1.seek(0)
# Out:
# 0

# %%
print(f1.tell())
# Out:
# 0

# %%
f1 = open("file4.txt", "x")

# %%
"""
Welcome to Python
"""
# Out:
# '\nWelcome to Python\n'

# %%
f1=open("file4.txt", "r+")

# %%
print(f1.tell())
# Out:
# 0

# %%
f1.write("this")
# Out:
# 4

# %%
print(f1.tell())
# Out:
# 4

# %%
f1.seek(0)
# Out:
# 0

# %%
print(f1.read())
# Out:
# thisome to Python

# %%
f1.write("this is ist lecture")
# Out:
# 19

# %%
print(f1.read())

# %%
  #if the process is read  and then write

# %%
#if we want to modify the content then we will open the file in r+ mode

# %%
print(f1.tell())
# Out:
# 0

# %%
f1 = open("file5.txt", "x")

# %%
f1 = open("file5.txt", "r+")

# %%
print(f1.tell())
# Out:
# 0

# %%
f1.write("Hi")
# Out:
# 2

# %%
print(f1.tell())
# Out:
# 2

# %%
print(f1.read())

# %%
f1.seek(0)
# Out:
# 0

# %%
print(f1.tell())
# Out:
# 0

# %%
print(f1.read())
# Out:
# Hi

# %%
print(f1.tell())
# Out:
# 2

# %%
f1.write("let c")
# Out:
# 5

# %%
print(f1.read())

# %%
f1.seek(0)
# Out:
# 0

# %%
print(f1.read())
# Out:
# Hilet c

# %%
# !git clone https://github.com/Tousyf/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 4, done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 4
# Receiving objects: 100% (4/4), done.

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/cnn_dailymail
# Out:
# /content/drive/MyDrive/cnn_dailymail

# %%
# !pwd
# Out:
# /content/drive/MyDrive/cnn_dailymail

# %%
#w+ mode

# %%
#it will overwrite the previous content and if file does not exists it will create new file

# %%
cd /content/sample_data
# Out:
# /content/sample_data

# %%
cd /content/
# Out:
# /content

# %%
f1 = open("file6.txt", "w+")

# %%
print(f1.tell())
# Out:
# 0

# %%
f1.write("welcome")
# Out:
# 7

# %%
print(f1.tell())
# Out:
# 7

# %%
f1.write("This is file handling")
# Out:
# 21

# %%
print(f1.tell())
# Out:
# 28

# %%
f1.seek(0)
# Out:
# 0

# %%
data1 = f1.read()

# %%
print(data1)
# Out:
# welcomeThis is file handling

# %%
print(f1.tell())
# Out:
# 28

# %%
f1 = open("file11.text", "x")

# %%
#This is a mode

# %%
f1 = open("file11.text", "a")

# %%
print(f1.tell())
# Out:
# 0

# %%
#print(f1.read())

# %%
f1.write("And we have just executed successfully")
# Out:
# 38

# %%
print(f1.tell())
# Out:
# 72

# %%
f1 = open("file11.text", "a+")#the cursor is always at the end of file

# %%
print(f1.tell())
# Out:
# 72

# %%
f1.seek(0)
# Out:
# 0

# %%
print(f1.read())
# Out:
# this is 2nd class on file handlingAnd we have just executed successfully

# %%
f1.seek(0)
# Out:
# 0

# %%
f1.seek(0)
# Out:
# 0

# %%
print(f1.read())
# Out:
# This is a modeAnd we have just executed successfully

# %% [markdown]
# **bold text**

# %% [markdown]
# **Binary Files**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
f1 = open("/content/drive/MyDrive/Image_Database_1/1229 (1).jpg", "rb")

# %%
print(f1.read())
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x02\x00\x02\x00\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\x83\x84\x85\x86\x87\x88\x89\x8a\x92\x93\x94\x95\x96\x97\x98\x99\x9a\xa2\xa3\xa4\xa5\xa6\xa7\xa8\xa9\xaa\xb2\xb3\xb4\xb5\xb6\xb7\xb8\xb9\xba\xc2\xc3\xc4\xc5\xc6\xc7\xc8\xc9\xca\xd2\xd
# ...

# %%
#in order to move this file to other file

# %%
# !pwd
# Out:
# /content

# %%
f2 = open("my_image1.jpg", "wb")
for i in f1:
  f2.write(i)

# %% [markdown]
# **Exception handling**

# %%
int1 = 100
int2 = 0
result = int1/int2
print(result)
print(int1)
print(int2)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-18-45438127569e> in <cell line: 3>()
#       1 int1 = 100
#       2 int2 = 0
# ----> 3 result = int1/int2
#       4 print(result)
#       5 print(int1)
#
# ZeroDivisionError: division by zero

# %%
int1 = 100
int2 = "hello"
result2 = int1 + int2
print(result2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-36197cdd11b3> in <cell line: 3>()
#       1 int1 = 100
#       2 int2 = "hello"
# ----> 3 result2 = int1 + int2
#       4 print(result2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#exception is an event that which occurs during the execution of program that disrupts normal flow of program

# %%
#errors cannot be handled while eceptions can be handled

# %%
"""

four blocks to handle the exception:
1. try block
2. except Block
3. else block
4. finally block
"""

# %%
"""
Syntax:
try:
  suspicious code
except [name of exception]:
  code t handle the exception (if occured)
else:
  code if no exception occured
finally:
  always exceuted......closing of file

else and finally are optional
  """

# %%
int1 = int(input("enter the first number"))
int2 = int(input("enter the second number"))


try:
  result = int1/int2
  print(result)
except ZeroDivisionError:
  print("division by zero is not possible")

#else:
 # print(result)
print(int1)
#finally:
 # print("hello")
# Out:
# enter the first number10
# enter the second number0
# division by zero is not possible
# 10

# %%
#multiple exceptions

int1 = int(input("enter the first number"))
int2 = int(input("enter the second number"))


try:
  result = int1/int2
  print(result1)
#except ZeroDivisionError:
except (ZeroDivisionError, NameError) as obj:
  print(obj)


#except NameError:
#  print("Variable name is wrong")

#else:
 # print(result)
print(int1)
print("hello")
#finally:
 # print("hello")
# Out:
# enter the first number10
# enter the second number0
# division by zero
# 10

# %%
5#multiple exceptions

int1 = int(input("enter the first number"))
int2 = int(input("enter the second number"))


try:
  result = int1/int2
  print(result1)
#except ZeroDivisionError:
except (ZeroDivisionError, NameError) as obj:
  print(obj)


#except NameError:
 # print("Variable name is wrong")

#else:
 # print(result)
print(int1)
#finally:
 # print("hello")
# Out:
# enter the first number10
# enter the second number0
# division by zero
# 10

# %%
#multiple exceptions

int1 = int(input("enter the first number"))
int2 = int(input("enter the second number"))


try:
  result = int1/int2
  print(result1)
except:
  print("An Exception error")





print(int1)
# Out:
# enter the first number10
# enter the second number5
# An Exception
# 10

# %%
#multiple exceptions

int1 = int(input("enter the first number"))
int2 = int(input("enter the second number"))


try:
  result = int1/int2
  print(result)
#except ZeroDivisionError:
except (ZeroDivisionError, NameError):
  print("division by zero is not possible")




else:
  print("No error occured")
finally:
  print("Always executed")
print(int1)
#finally:
 # print("hello")
# Out:
# enter the first number10
# enter the second number5
# 2.0
# No error occured
# Always executed
# 10

# %% [markdown]
# **When you dont know which error occured**

# %%
#multiple exceptions

int1 = int(input("enter the first number"))
int2 = int(input("enter the second number"))


try:
  result = int1/int2
  print(result1)
except Exception as i:
  print(i)

  print(i.__class__)

  1
#else:
 # print(result)
print(int1)
#finally:
 # print("hello")
# Out:
# enter the first number10
# enter the second number0
# division by zero
# <class 'ZeroDivisionError'>
# 10

# %%
#multiple exceptions
import sys
int1 = int(input("enter the first number"))
int2 = int(input("enter the second number"))


try:
  result = int1/int2
  print(result1)
except:
  #print(sys.exc_info()[0])
  print(sys.exc_info()[1])


#else:
 # print(result)
print(int1)
#finally:
 # print("hello")
# Out:
# enter the first number10
# enter the second number5
# name 'result1' is not defined
# 10

# %% [markdown]
# 5**Raise Function**

# %%
#user defined exception....withdrawing money 12000 and contain 10000...and programmer defined exceptions for this....

# %%
#raise keyword is used to call any exception on any particular condition

# %%
#syntax...raise ExceptionName ("exception message")

# %%
try:
  age = int(input("enter your age"))
  if age<0:
    raise ValueError("You have entered wrong input")
  print("your age is ", age)
except ValueError as var:
  print(var)

print("rest of code")
# Out:
# enter your age-2
# You have entered wrong input
# rest of code

# %%
#With Statement assignment...
